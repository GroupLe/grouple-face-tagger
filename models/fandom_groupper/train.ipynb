# %%
import pandas as pd
import json
import matplotlib.pyplot as plt

# %%
root = '../characters_parser/data/'

# %%
ydf1 = pd.read_csv(root + 'you_anime_characters_refs.csv', sep='\t')
ydf1['anime_url'] = ydf1.page_link.apply(lambda s: s.split('/')[-1])

ydf2 = pd.read_csv(root + 'you_anime_refs.csv', sep='\t')
ydf2['anime_url'] = ydf2.link.apply(lambda s: s.split('/')[-1])

ydf = pd.merge(ydf1, ydf2, on='anime_url')
ydf = ydf['title name'.split()]

ydf.title = ydf.title.apply(str.strip)
ydf.name = ydf.name.apply(str.strip)

ydf = ydf.sort_values(by='title')

ydf.head(3)
# Out:
#                    title       name
# 87902  .хак//Вернувшийся        Ята
# 87914  .хак//Вернувшийся      Matsu
# 87913  .хак//Вернувшийся  Pilocchio

# %%
ydf_small = ydf[:int(len(ydf)*0.2)]

# %%
from groupper import PersonIntersectionGroupper

# %%
groupper = PersonIntersectionGroupper(df=ydf)
# Out:
# 100%|█████████▉| 6820/6821 [11:44<00:00,  9.68it/s]

# %%
len(groupper.groups)
# Out:
# 3783

# %%
groupper.save('./groupper_model.pkl')

# %%
groupper = PersonIntersectionGroupper(path='./groupper_model.pkl')

# %%
def select_popular(groups):
    names = ['Наруто', 'Блич', 'Ван-Пис', 'Атака', 'Баскетбол', 'Бездомный', 'Волейбол', 'Гинтама', 'Граница']
    pure_groups = []
    for g in groups:
        for title in g.titles:
            for name in names:
                if name in title.orig_name:
                    pure_groups.append(g)
                    break
            else:
                continue
            break
    return pure_groups

# %%
pop_gr = select_popular(groupper.groups)
print('\n\n'.join(list(map(str, pop_gr))))
# Out:
# All persons n 249
# 15 творцов аниме 2
# Голова-гора 1
# Голубые небеса Ромео 61
# Госпожа Умница 9
# Добро пожаловать, Титосэ-тян 1
# Долгих лет жизни, предки! 6
# Дракула 4
# Звездный Орфей 1
# Звёздные рыцари со звезды изгоев 63
# Звёздные рыцари со звезды изгоев: Спецвыпуски 6
# Конан — мальчик из будущего. Фильм 2 2
# Кошачьи истории 1
# Мароко 1
# Мобильный воин ГАНДАМ: Дополнительная информация по Вселенскому Веку 1
# Наруто: Весна юности Рока Ли 72
# Наруто: Джин и три желания! 14
# Наруто: Найти тёмно-красный четырёхлистный клевер! 6
# Наруто: Наконец-таки! Соревнования дзёнинов против гэнинов! 29
# Наруто: Пересечение дорог 8
# Наруто: Пылающий экзамен на тюнина! Наруто против Конохамару! 13
# Наруто: Ураганные хроники 2 — Связи 19
# Наруто: Ураганные хроники 3 — Наследники воли огня 30
# Наруто: Ураганные хроники 5 — Кровавая тюрьма 30
# Наруто: Ураганные хроники 6 — Путь ниндзя 42
# Наруто: Ураганные хроники — Битва с яичницей-глазуньей 3
# Наруто: Ураганные хроники — Школа Конохи 23
# Стеклянный океан 1
# Тайна морского котика 1
# Удивительные приключения Панды 1
# Ями Шибаи: Японские рассказы о привидениях 1
# Ями Шибаи: Японские рассказы о привидениях 2 1
# Ями Шибаи: Японские рассказы о привидениях 3 1
# Ями Шибаи: Японские рассказы о привидениях 4 1
# Ями Шибаи: Японские рассказы о привидениях 5 1
# Ями Шибаи: Японские рассказы о привидениях 6 1
# Наруто х UT 12
# Наруто: Спортивный фестиваль Конохи 42
#
# All persons n 309
# KFC Китай и Гинтама 3
# Гинтама 222
# Гинтама 2 104
# Гинтама 3 39
# Гинтама 4 69
# Гинтама 4: Любовные благовония 9
# Гинтама 5 27
# Гинтама 6 45
# Гинтама 7 64
# Гинтама 8 35
# Гинтама x Фасоль 6
# Гинтама: Грандиозное собрание 8
# Гинтама: Джамп Феста 2005 17
# Гинтама: Джамп Феста 2014 19
# Гинтама: Джамп Феста 2015 14
# Гинтама: Лучшее из «Гинтамы» на Theater 2D 32
# Гинтама: Рождение Белого Демона 14
# Гинтама: Сказание о Бэнидзакуре 32
# Гинтама: Сказание о Бэнидзакуре — Дополнение 3
# Гинтама: Финальная арка — Ёродзуя навсегда! 24
# Лапша быстрого приготовления «Ниссин» x Гинтама 6
# Сбережения Таскэ Шибары 1
# Скет Данс: Прояснение 3
#
# All persons n 99
# Атака титанов 74
# Атака титанов 2 45
# Атака титанов OVA 28
# Атака титанов: Багровые луки и стрелы 39
# Атака титанов: Выбор без сожалений 9
# Атака титанов: Крылья свободы 38
# Атака титанов: Оборона «Skytree» 9
# Атака титанов: Рекап 18
# Атака титанов: Театр с монстрами — Вперёд, кадетский корпус! 21
# Атака титанов: Финал 20
# Атака! Титаны средней школы 41
#
# All persons n 47
# Атака титанов 3 47
#
# All persons n 13
# Атака титанов: Потерянные девушки 13
#
# All persons n 93
# Баскетбол Куроко 47
# Баскетбол Куроко 2 60
# Баскетбол Куроко 2: Спецвыпуски 31
# Баскетбол Куроко 3 73
# Баскетбол Куроко 3: Спецвыпуски 11
# Баскетбол Куроко: Вбрасывание 7
# Баскетбол Куроко: Вперёд сквозь слёзы 18
# Баскетбол Куроко: Давайте поболтаем 13
# Баскетбол Куроко: Давайте поболтаем 2 28
# Баскетбол Куроко: Давайте поболтаем 3 2
# Баскетбол Куроко: Дураки не могут выиграть! 14
# Баскетбол Куроко: Не делай так больше 9
# Баскетбол Куроко: Открывая двери 31
# Баскетбол Куроко: Последняя игра 36
# Баскетбол Куроко: Спецвыпуски 20
# Баскетбол Куроко: Тень и свет 14
# Баскетбол Куроко: Это лучший подарок! 14
#
# All persons n 45
# Баскетбольный клуб! 26
# Баскетбольный клуб! OVA 10
# Баскетбольный клуб! SS 40
#
# All persons n 55
# Бездомный бог 32
# Бездомный бог OAD 22
# Бездомный бог: Арагото 44
# Бездомный бог: Арагото OAD 18
#
# All persons n 10
# Бездомный мальчик Реми 10
#
# All persons n 287
# Блич 274
# Блич: Воспоминания ни о ком 41
# Блич: Воспоминания под дождём 12
# Блич: Восстание алмазной пыли 43
# Блич: Глава из Ада 23
# Блич: Неистовство заточённого меча 35
# Блич: Уходя в пустоту - я зову тебя по имени 32
#
# All persons n 461
# Боруто 48
# Боруто: День, когда Наруто стал хокагэ 11
# Боруто: Джамп Феста 2016 10
# Боруто: Новое поколение Наруто 103
# Наруто: Последний фильм 35
# Наруто: Ураганные хроники 402
# Наруто: Ураганные хроники 4 — Затерянная башня 21
# Однажды мне пришло письмо из Страны собак 1
# Покинутый котёнок Тора 1
# Котёнок Тора и насекомые 1
# Наруто: Битва на Хидден-Фолс 6
#
# All persons n 837
# Ван-Пис 745
# Ван-Пис 3D 2
# Ван-Пис 3D2Y: Пережить смерть Эйса! Обещание Луффи своим накама 40
# Ван-Пис 3D: Погоня за соломенной шляпой 13
# Ван-Пис: Z 25
# Ван-Пис: Барон Омацури и Секретный Остров 21
# Ван-Пис: Воспоминания детектива в соломенной шляпе 33
# Ван-Пис: Гигантский механический солдат замка Каракури 12
# Ван-Пис: Жестокий мир 24
# Ван-Пис: Жестокий мир — Эпизод 0 78
# Ван-Пис: Запасной план. Идеальный метод захвата Ван-Пис 5
# Ван-Пис: Защитить! Последнее великое представление! 10
# Ван-Пис: Золото 24
# Ван-Пис: Золото — Эпизод 0 9
# Ван-Пис: Золотое сердце 18
# Ван-Пис: Королевство Чоппера на Острове Необычных Животных 13
# Ван-Пис: Крик сердца 2
# Ван-Пис: Начало приключений 14
# Ван-Пис: Остров мечты 9
# Ван-Пис: Открытие в большом море! Большая мечта отца! 14
# Ван-Пис: Победить пирата Ганзака! 6
# Ван-Пис: Приключение в Алабасте — Принцесса пустыни и пираты 26
# Ван-Пис: Приключение в Небуландии 18
# Ван-Пис: Приключение в глуби океана 8
# Ван-Пис: Приключения в Алабасте — Пролог 8
# Ван-Пис: Проклятие Святого Меча 16
# Ван-Пис: Путешествие в один конец 21
# Ван-Пис: Рекап 5
# Ван-Пис: Танцевальный марафон Джанго 6
# Ван-Пис: Театр Мугивары 9
# Ван-Пис: Футбольный король мечты 15
# Ван-Пис: Цельсь! Пиратские короли бейсбола 13
# Ван-Пис: Эпизод Ист Блю — Большое приключение Луффи и его команды 27
# Ван-Пис: Эпизод Луффи — Приключения на Ладоневом острове 24
# Ван-Пис: Эпизод Мерри — История об ещё одном накаме 23
# Ван-Пис: Эпизод Нами — Слёзы навигатора и узы друзей 16
# Ван-Пис: Эпизод Сабо — Узы трёх братьев, чудесное воссоединение и унаследованная воля 56
# Ван-Пис: Эпизод Чоппера Плюс — Зимнее цветение, чудесная сакура 19
# Серена x Ван-Пис 3D: Погоня за Соломенной шляпой — Проникновение! Таузенд Санни! 9
#
# All persons n 23
# Ван-Пис (2000) 13
# Ван-Пис: Приключение на Заводном Острове 17
#
# All persons n 117
# Волейбол против «Неудачников»!! 17
# Волейбол!! 63
# Волейбол!! 2 84
# Волейбол!! 3 41
# Волейбол!! 3 OVA 7
# Волейбол!! К вершине 22
# Волейбол!! Мультипликационная квест-история 6
# Волейбол!! Начало и конец 25
# Волейбол!! Победители и проигравшие 26
# Волейбол!! Прибытие Льва Хайбы 19
#
# All persons n 8
# Волейбольный клуб старшей школы Сэйин 8
#
# All persons n 11
# Граница 11
#
# All persons n 106
# Граница пустоты 1: Вид с высоты 5
# Граница пустоты 2: Теория убийства— Часть 1 7
# Граница пустоты 3: Оставшееся чувство боли 7
# Граница пустоты 4: Храм пустоты 7
# Граница пустоты 5: Спираль парадокса 10
# Граница пустоты 6: Мелодия забвения 10
# Граница пустоты 7: Теория убийства — Часть 2 9
# Граница пустоты 8: Эпилог 2
# Граница пустоты: Благословение будущего 9
# Граница пустоты: Благословение будущего — Дополнительная глава 7
# Граница пустоты: Благословение будущего — Интро 4
# Граница пустоты: Кинозаставки 4
# Граница пустоты: Компиляция — Врата седьмого неба 6
# Карнавальный фантазм 61
# Карнавальный фантазм: Крепость Иллии 13
# Карнавальный фантазм: Прошлый сезон 25
# Карнавальный фантазм: ХибиТика 24
# Повесть о лунной принцессе 11
# Сегодняшнее меню для Эмии 17
# Судьба/Девочка-волшебница Иллия: Клятва под снегом — Спешл 2
# Судьба/Начало: Кафе 10
# Судьба/Начало: Пожалуйста! Консультация с Айнцберн 6
# Судьба/Ночь схватки 23
# Судьба/Ночь схватки: Бесконечный мир клинков 2 21
# Судьба/Ночь схватки: Бесконечный мир клинков 2 — Солнечный день 3
# Судьба/Ночь схватки: Бесконечный мир клинков — Пролог 13
# Судьба/Ночь схватки: Прикосновение небес 23
# Судьба/Ночь схватки: Прикосновение небес 2 15
# Судьба/Ночь схватки: Прикосновение небес 3 2
# Судьба/Ночь схватки: Репродукция 17
# Судьба/Девочка-волшебница Иллия: Спешлы 9
# Судьба/Девочка-волшебница Иллия 21
# Судьба/Девочка-волшебница Иллия 2 21
# Судьба/Девочка-волшебница Иллия 2 OVA 10
# Судьба/Девочка-волшебница Иллия 2: Продолжение 27
# Судьба/Девочка-волшебница Иллия 2: Продолжение — Спешлы 17
# Судьба/Девочка-волшебница Иллия 2: Спешлы 15
# Судьба/Девочка-волшебница Иллия OVA 13
#
# All persons n 499
# Инадзума 11 350
# Инадзума 11: Атака сильнейшей армии Огр 38
# Инадзума 11: Весы Ареса 73
# Инадзума 11: Внешний код 11
# Инадзума 11: Матч мечты в ультра-измерении 11
# Инадзума 11: Только вперёд! 147
#
# All persons n 201
# Наруто 195
# Наруто: Ураганные хроники 1 — Адепты Тёмного царства 20
#
# All persons n 11
# Наруто 1: Книга искусств ниндзя Снежной принцессы 11
#
# All persons n 11
# Наруто 2: Большое столкновение! Призрачные руины в глубине земли 11
#
# All persons n 8
# Наруто 3: Грандиозный переполох! Бунт зверей на острове Миказуки! 8

# %%
print('\n\n'.join(list(map(str, groupper.groups[:50]))))
# Out:
# All persons n 41
# .хак//Вернувшийся 19
# .хак//Вернувшийся 19
# .хак//Корни 33
# .хак//Трилогия 18
# .хак//Трилогия: Режим пародии 13
#
# All persons n 26
# .хак//ЗНАК 17
# .хак//Интермедия 3
# .хак//Унисон 19
#
# All persons n 10
# .хак//Квантум 10
# .хак//Квантум: Вперёд, наши куранты! 4
#
# All persons n 19
# .хак//Легенда сумеречного браслета 19
# .хак//Легенда сумеречного браслета: Автономное собрание 6
#
# All persons n 11
# .хак//Переходная стадия 11
#
# All persons n 8
# .хак//По ту сторону мира 7
# .хак//Противостояние: Доклад "Танатос" 3
#
# All persons n 40
# 009 Ответ: Киборг 10
# Киборг 009 52
# Киборг 009 vs. Человек-дьявол 29
# Киборг 009 и войны монстров 11
# Киборг 009: Возобновление 3
# Киборг 009: Легенда о Супер-Галактике 8
# Звериный остров сокровищ 1
#
# All persons n 18
# 11 глаз 18
# 11 глаз: Спецвыпуск 14
# 11 глаз: Спецвыпуски 5
#
# All persons n 9
# 12 лет: Биение маленького сердца 7
# 12 лет: Биение маленького сердца 2 8
# 12 лет: Поцелуй, ненависть, любовь 9
#
# All persons n 249
# 15 творцов аниме 2
# Голова-гора 1
# Голубые небеса Ромео 61
# Госпожа Умница 9
# Добро пожаловать, Титосэ-тян 1
# Долгих лет жизни, предки! 6
# Дракула 4
# Звездный Орфей 1
# Звёздные рыцари со звезды изгоев 63
# Звёздные рыцари со звезды изгоев: Спецвыпуски 6
# Конан — мальчик из будущего. Фильм 2 2
# Кошачьи истории 1
# Мароко 1
# Мобильный воин ГАНДАМ: Дополнительная информация по Вселенскому Веку 1
# Наруто: Весна юности Рока Ли 72
# Наруто: Джин и три желания! 14
# Наруто: Найти тёмно-красный четырёхлистный клевер! 6
# Наруто: Наконец-таки! Соревнования дзёнинов против гэнинов! 29
# Наруто: Пересечение дорог 8
# Наруто: Пылающий экзамен на тюнина! Наруто против Конохамару! 13
# Наруто: Ураганные хроники 2 — Связи 19
# Наруто: Ураганные хроники 3 — Наследники воли огня 30
# Наруто: Ураганные хроники 5 — Кровавая тюрьма 30
# Наруто: Ураганные хроники 6 — Путь ниндзя 42
# Наруто: Ураганные хроники — Битва с яичницей-глазуньей 3
# Наруто: Ураганные хроники — Школа Конохи 23
# Стеклянный океан 1
# Тайна морского котика 1
# Удивительные приключения Панды 1
# Ями Шибаи: Японские рассказы о привидениях 1
# Ями Шибаи: Японские рассказы о привидениях 2 1
# Ями Шибаи: Японские рассказы о привидениях 3 1
# Ями Шибаи: Японские рассказы о привидениях 4 1
# Ями Шибаи: Японские рассказы о привидениях 5 1
# Ями Шибаи: Японские рассказы о привидениях 6 1
# Наруто х UT 12
# Наруто: Спортивный фестиваль Конохи 42
#
# All persons n 3
# 21 Эмон 3
#
# All persons n 12
# 22/7 8
# Девочки дня 12
#
# All persons n 3
# 25-летняя старшеклассница 3
#
# All persons n 19
# 3000 миль в поисках матери 19
# Марко 1
#
# All persons n 17
# 3x3 глаза 16
# 3х3 глаза: Сказание Сэймы 5
#
# All persons n 27
# 7 самураев 24
# Семья Ямада 1
# Счастливый мир! 4
#
# All persons n 8
# 7 семян 8
#
# All persons n 30
# 91 день 30
# 91 день: День 13 10
# 91 день: Рекап 20
# 91 изумление 3
#
# All persons n 12
# A.I.C.O.: Инкарнация 12
#
# All persons n 18
# A3! Весна и лето 18
#
# All persons n 8
# ARP. Пропуск в закулисье 8
#
# All persons n 46
# All-Free kono Natsu Ichioshi Monogatari Campaign Kokuchi Douga 6
# Mutsugo to Ouma no Monogatari 6
# Осомацу 27
# Осомацу-кун: Привет всем из звёздного арбуза! 6
# Осомацу-сан 36
# Осомацу-сан (2016) 15
# Осомацу-сан 2 28
# Осомацу-сан. Фильм 12
# Осомацу-сан: Серия коротких фильмов 7
# Осомацу-сан: Спешл 6
# Осомацу: Спецвыпуск 1
#
# All persons n 4
# Chokkyuu Hyoudai Robot Anime: Straight Title 4
#
# All persons n 8
# Chou Henshin Cosprayers vs. Ankoku Uchuu Shougun the Movie 5
# Жрицы мира 5
# Жрицы мира: Спецвыпуски 5
# Любовь любовь? 8
# Любовь любовь? Спецвыпуски 8
# Сногсшибательно! 6
# Сногсшибательно! Спецвыпуски 2
#
# All persons n 512
# Chou Zenmairobo: Patrasche 6
# Свой вклад 1
# Стеклянная маска 26
# Стеклянная маска третьего D-класса 5
# Что случается перед войной? 1
# Японские народные сказки 2
# Покемон: Пичу и Пикачу 7
# Покемон: Путешествие Эша 5
# Покемон: Таинственное подземелье — Врата в бесконечность 1
# Toho Cinemas x Pokemon Go 1
# Покемон: Летние каникулы Пикачу 7
# Покемон: Пикачу зимой 6
# Покемон: Пикачу зимой (2000) 8
# Покемон: Пикачу зимой (2001) 6
# Покемон: Пикачу и летняя история на мосту 3
# Покемон: Пикачу и оркестр покемонов 4
# Покемон: Появление призрачного покемона Лугии 21
# Покемон: Приключение Пикачу на острове 4
# Покемон: Рэйнджер и Храм моря 19
# Покемон: Секретная база пляшущих покемонов 7
# Покемон: Селеби, голос леса 15
# Покемон: Серенада Мелоэтты 5
# Покемон: Современное поколение 206
# Покемон: Современное поколение — Дзирати исполнитель желаний 15
# Покемон: Современное поколение — Лукарио и загадка Мью 15
# Покемон: Солнце и Луна 61
# Покемон: Спасательная миссия Пикачу 9
# Покемон: Судьба Деоксиса 13
# Покемон: Тайный властитель миражных покемонов 19
# Покемон: Фестиваль привидений Пикачу 4
# Покемон: Хранители водной столицы — Латиас и Латиос 14
# Покемон: Хроники приключений 43
# Синий демон 5
# Снег 1
# Страшные истории из школы: Пришла Ханако 1
# Сугио 1
# День гнева: Воспоминания Мари 1
# Иви и красочные друзья 1
# Когда ты отвернёшься 1
# Покемон 122
# Покемон: Алмаз и жемчуг 98
# Покемон: Алмаз и жемчуг — Гиратина и небесный букет Шейми 16
# Покемон: Большое ледяное приключение Пикачу 4
# Покемон: Друзья Пикачу и Иви 6
# Покемон: Загадочное приключение Пикачу 4
# Покемон: Захватывающие прятки Пикачу 5
# Покемон: Император хрустальной башни — Энтэй 20
# Покемон: Клуб исследований Пикачу 4
# Покемон: Летний фестиваль Пикачу 4
# Покемон: Мьюту наносит ответный удар 21
# Покемон: Мьюту! Я существую! 15
# Покемон: Наилучших благ! 2 — Приключения на островах Деколора 35
# Покемон: Наилучших благ! Сезон 2 — Приключения Деколоры. Спецвыпуск 4
# Покемон: Наилучших благ! Сезон 2: Сверхскоростной Генесект — Пробуждение Мьюту 9
# Покемон: Омега Руби и Альфа Сапфир 6
# Покемон: Песнь Мелоэтты — Поиск рыночных ягод 5
# Покемон: Пикачу в поисках сокровищ! 4
# Покемон: Пикачу, от чего этот ключ? 8
# Покемон: Райко — легенда грома 12
# Рейнджер-покемон: Путь света 1
# Уиз 1
# Два самурая 1
# Девушка со спичками 1
# Опасайтесь огня: Опенинг 1
# Повесть эпохи Гэнроку: Санкити и Осаё 1
#
# All persons n 3
# Choubakumatsu Shounen Seiki Takamaru 3
#
# All persons n 7
# Choujuu Kishin Dancougar: God Bless Dancougar 5
# Данкугар 7
#
# All persons n 3
# Chuuko Video-ya no Onna Tenin X 3
#
# All persons n 6
# DAKAICHI. Мой номер 1 6
#
# All persons n 7
# DS Anime Soushuuhen '98 7
#
# All persons n 2
# Domo TV 2
# Домо-кун 2
#
# All persons n 11
# Dorami & Doraemons: Space Land's Critical Event 8
# The☆Doraemons: Dokidoki Kikansha Daibakusou! 7
# The☆Doraemons: Mushimushi Pyonpyon Daisakusen! 10
# Дораэмоны: Таинственный вор Дорапан 7
#
# All persons n 4
# Elite Jack!! 4
#
# All persons n 6
# Fantasista Stella 6
#
# All persons n 4
# Ganbare!! Tabuchi-kun!! Aa Tsuppari Jinsei 4
# Дерзай, Табучи-кун! 3
# Дерзай, Табучи-кун! Ожесточённое соревнование 4
#
# All persons n 12
# Green Dakara x Ученик чудовища 4
# Ученик чудовища 12
#
# All persons n 10
# H2O: Следы на песке 10
#
# All persons n 1
# Hakusai Anime 1
#
# All persons n 11
# Happy☆Lesson: Hoka Hoka★Kanna to Futari Kiri 1
# Счастливый урок 20
# Счастливый урок: Успех 11
# Счастливый урок: Финал 11
#
# All persons n 12
# Hoshi no Kirby: Taose!! Koukaku Majuu Ebizou 5
# Звезда Кирби 12
#
# All persons n 16
# ID: Вторжение 16
#
# All persons n 1
# Install Pilot 1
#
# All persons n 128
# It's a Rumic World: 50th Anniversary Weekly★Shonen Sunday 5
# Инуяся: Чёрная Тэссайга 3
# Несносные пришельцы: Заплыв с препятствиями 24
# Инуяся: Любовь, превозмогающая время 19
# Инуяся: Меч, покоряющий мир 19
# Инуяся: Пламя острова Хорай 15
# Инуяся: Последний акт 34
# Инуяся 91
# Инуяся: Замок в зазеркалье 20
#
# All persons n 309
# KFC Китай и Гинтама 3
# Гинтама 222
# Гинтама 2 104
# Гинтама 3 39
# Гинтама 4 69
# Гинтама 4: Любовные благовония 9
# Гинтама 5 27
# Гинтама 6 45
# Гинтама 7 64
# Гинтама 8 35
# Гинтама x Фасоль 6
# Гинтама: Грандиозное собрание 8
# Гинтама: Джамп Феста 2005 17
# Гинтама: Джамп Феста 2014 19
# Гинтама: Джамп Феста 2015 14
# Гинтама: Лучшее из «Гинтамы» на Theater 2D 32
# Гинтама: Рождение Белого Демона 14
# Гинтама: Сказание о Бэнидзакуре 32
# Гинтама: Сказание о Бэнидзакуре — Дополнение 3
# Гинтама: Финальная арка — Ёродзуя навсегда! 24
# Лапша быстрого приготовления «Ниссин» x Гинтама 6
# Сбережения Таскэ Шибары 1
# Скет Данс: Прояснение 3
#
# All persons n 8
# Kaibutsu-kun: Kaibutsu Land e no Shoutai 4
# Кайбуцу-кун (1980) 8
#
# All persons n 90
# Kaiketsu Zorori Da-Da-Da-Daibouken! 1
# Kaiketsu Zorori: Mamoru ze! Kyouryuu no Tamago 1
# Удивительный Зорори 7
# Кэроро 12
# Сержант Кэроро 130
#
# All persons n 9
# Kingdom Hearts χ Back Cover 9
#
# All persons n 5
# Kira Kira 5th Anniversary Live Anime: Kick Start Generation 5
#
# All persons n 1
# Kougyou Aika Volley Boys 1
#
# All persons n 1
# Majin Sentai Death Ranger: Ubawareta Pudding! 1
