# %%
from transformers import BertTokenizer
import torch
import torch.nn as nn

from models import BertLstm
# Out:
# wandb: WARNING W&B installed but not logged in.  Run `wandb login` or set the WANDB_API_KEY env variable.

# %%
tokenizer = BertTokenizer.from_pretrained('DeepPavlov/rubert-base-cased-conversational')
model = BertLstm(2)
model.load('./weights/ner_model.pt')
model = model#.to('cuda')

# %%
s = open('./data/augmented_30_comments/test.txt').read().split('\n\n')

def conll_to_str(conll: str):
    tokens = conll.splitlines()
    words = list(map(lambda s: s.split()[0], tokens))
    return ' '.join(words)

# %%
sents = list(map(conll_to_str, s))
sents[:10]
# Out:
# ['Так Нанпо не вампир Он собачка',
#  'Яойный Ту Дум привык когда на него набрасываются Спейд это же Асука говорит',
#  'Вот облом Амельда как ты мог',
#  'хороший салют Син',
#  'меня терзают смутные подозрения что это то дерево директрисы',
#  'я всю эту манхву как темноволосая тян с Айкс Тиссоку',
#  'Можно провести аналогию с Хинако там такая же форма правления',
#  'я всю эту манхву как темноволосая тян с Адзума Прецель',
#  'Сёкити когда я привыкну',
#  'Соска на 4 ом фрейме словно фанатка kpopa увидевшая кумира А потом еще и Тэрасаки ему']

# %%
for sent in sents[:50]:
    names = model.get_names(sent)
    print(sent, names)
#     t = torch.LongTensor(tokenizer.encode(sent)).unsqueeze(0)
#     word_embs, sent_emb = model.bert(t)
#     preds = model.lin(word_embs).argmax(dim=2).tolist()[0]
    
#     wps, labels = postprocess(tokenizer.tokenize(sent), preds)
    
#     sent = ' '.join(wps)
#     names = [wps[i] if '1' in labels[i] else None for i in range(len(wps))]
#     names = list(filter(lambda x: x is not None, names))
    
#     print(sent, names)
# Out:
# Так Нанпо не вампир Он собачка ['Нанпо']
# Яойный Ту Дум привык когда на него набрасываются Спейд это же Асука говорит ['Асука']
# Вот облом Амельда как ты мог ['Амельда']
# хороший салют Син ['Син']
# меня терзают смутные подозрения что это то дерево директрисы ['директрисы']
# я всю эту манхву как темноволосая тян с Айкс Тиссоку ['Айкс', 'Тиссоку']
# Можно провести аналогию с Хинако там такая же форма правления ['Хинако']
# я всю эту манхву как темноволосая тян с Адзума Прецель ['Адзума', 'Прецель']
# Сёкити когда я привыкну ['Сёкити']
# Соска на 4 ом фрейме словно фанатка kpopa увидевшая кумира А потом еще и Тэрасаки ему ['kpopa', 'Тэрасаки']
# Согласна с Sun Lynx они не братья Ал сказал ребятам что знает Аритоми благодаря ХОЗЯИНУ а не отцу ['Аритоми']
# Кадзанэ на 10 стр же показали что она его мать ['Кадзанэ']
# Реально на МидориИчинотани похож О о ['МидориИчинотани']
# ооо благодарю ООО это великолепно []
# Это цензура фигеет []
# Что с лицом Токунари ['Токунари']
# 2 фрейм у Сёдзиро встал на себя самого Оо ['Сёдзиро']
# Масоны блин свою гнут линию и даже Каку им не указ ['Каку']
# Я читаю и прям слышу голос Акаши сенсея ОО мозг сам воспроизводит ['Акаши']
# каким боком тут Муму ['Муму']
# я всю эту манхву как темноволосая тян с Фоэна Фуруки ['Фоэна', 'Фуруки']
# ПХАХ только Mrs. свои чувства не понял по этому так и не думал говорить ХД ['Mrs', '.']
# не люблю я груповуху ну как скажите мне в таком месте родится любовь ведь они тр хаться будут с кем []
# мда опять какая то бурная реакция []
# у него там точно только царапина или Мужчина ему ногу сейчас сломал ['Мужчина']
# Интересненько Спасибо за труд С нетерпение жду продолжения []
# да да согласна эх хотелось бы получить одно такое видео с Коки снизу 3 ['Коки']
# Так Дзинъэ знал что Алексий будет последней каплей ['Дзинъэ', 'Алексий']
# Че тут делают старые Хизуру и Вакай Лаадноо ['Хизуру', 'Вакай']
# Покупаю биле Ичиномия сколько стоит беру ['Ичиномия']
# Япония место где хрупкая 14 летняя девушка разнест Селестина как нефиг делать ['Селестина']
# мамина еда хахаха []
# Динхайм ты от куда вылез иди к Арата ['Динхайм', 'Арата']
# шикарная страничка []
# а вы тоже как только видите синяки на теле у малознакомых людей сразу набрасываетесь на них хватаете за руки и орете ЧТО ЭТО ВООБЩЕ ТАКОЕ []
# это любовь []
# Акира да зря я долго втыкала где люди Минори нашли ['Акира', 'Минори']
# Я тоже боюсь мне реально мерещится привидение у двери []
# прод к яойным онгоингам З ['онгоингам']
# Она точно Иджима ['Иджима']
# Anime Love 3 точно а ято думала что у Michiru-sensei такое личико шикарное XD ['Anime', 'Michiru', '-', 'sensei']
# Онемев восхищенно любуется на Казуо ['Казуо']
# спасибо тебе о великая Пумо вечер прожит не зря ['Пумо']
# хороший салют Аристотель ['Аристотель']
# KoibitoVera это Мерои из Поющий принц 2000 любовь ['Мерои']
# Вулфитян да все понятно конечно просто очень неприятно читать недоконченную работу ['Вулфитян']
# о не я один о Томонага вспомнил ['Томонага']
# Инбэ да зря я долго втыкала где люди Алексей нашли ['Инбэ']
# Шун Ты ли это ХD ['Шун']
# У Адати вс на мази ['Адати']
